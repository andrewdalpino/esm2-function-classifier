# %% [markdown]
# ## Generate the GO graph wrapper object and plot the depth histogram for molecular function

# %%
import matplotlib.pyplot as plt
import go_wrapper

go_graph = go_wrapper.GOGraph(go_fpath='../cafa-5-protein-function-prediction/Train/go-basic.obo')

depths = go_graph.compute_depths(go_wrapper.MF_ROOT_ID)

plt.hist(depths)
plt.xlabel('Depth')
plt.ylabel('Count')
plt.title('Depth (computed as shortest path the specified root ID) distribution of GO terms\n(MF root ID: {})'.format(go_wrapper.MF_ROOT_ID))
plt.show()
# Out:
# Parsing OBO file ../cafa-5-protein-function-prediction/Train/go-basic.obo
# Header {
#   "format-version": "1.2",
#   "data-version": "releases/2023-01-01",
#   "subsetdef": "prokaryote_subset \"GO subset for prokaryotes\"",
#   "synonymtypedef": "systematic_synonym \"Systematic synonym\" EXACT",
#   "default-namespace": "gene_ontology",
#   "ontology": "go"
# }
# Adding relationship types {'term_tracker_item', 'regulates', 'part_of', 'negatively_regulates', 'positively_regulates'}
# Namespaces to include {'biological_process', 'cellular_component', 'molecular_function'}
# Generated graph with 43248 nodes and 154155 edges
# Edge counts by type {
#   "PARENT": 69350,
#   "CHILD": 69350,
#   "part_of": 6851,
#   "regulates": 3157,
#   "negatively_regulates": 2729,
#   "positively_regulates": 2718
# }

# %% [markdown]
# ## Plot the subgraph for a given protein, showing the annotated true terms and predicted terms with only CHILD edges drawn.
# Nodes are colored green for true positives, red for false positives, and blue for false negatives
# This example is for predictions in the cellular component sub-ontology

# %%
this_true_terms = ['GO:0005575',
 'GO:0005622',
 'GO:0005737',
 'GO:0005783',
 'GO:0005829',
 'GO:0009507',
 'GO:0009526',
 'GO:0009534',
 'GO:0009535',
 'GO:0009536',
 'GO:0009579',
 'GO:0012505',
 'GO:0016020',
 'GO:0019867',
 'GO:0031090',
 'GO:0031967',
 'GO:0031968',
 'GO:0031976',
 'GO:0034357',
 'GO:0042170',
 'GO:0042651',
 'GO:0043226',
 'GO:0043227',
 'GO:0043228',
 'GO:0043229',
 'GO:0043231',
 'GO:0043232',
 'GO:0055035',
 'GO:0098588',
 'GO:0110165']

this_predicted_terms = ['GO:0005575',
 'GO:0005622',
 'GO:0005834',
 'GO:0005886',
 'GO:0009898',
 'GO:0016020',
 'GO:0019897',
 'GO:0019898',
 'GO:0031234',
 'GO:0032991',
 'GO:0043226',
 'GO:0043227',
 'GO:0098562',
 'GO:0098796',
 'GO:0110165',
 'GO:1905360']

go_graph.plot_go_subgraphs_true_vs_predicted(this_true_terms, this_predicted_terms, label_by_name=True)
# Out:
# (<Figure size 2400x2400 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## Other convenience methods

# %%
go_graph.namespaces
# Out:
# {'biological_process', 'cellular_component', 'molecular_function'}

# %%
import networkx as nx

# %%
nx.draw(p)

# %%
p = go_graph.G.subgraph(this_predicted_terms, )
nx.number_weakly_connected_components(p)
# Out:
# 1

# %%
go_graph.compute_excess_components(this_predicted_terms)
# Out:
# 0

# %%
dir(go_graph)
# Out:
# ['G',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'compute_depths',
#  'compute_excess_components',
#  'compute_excess_components_per_term',
#  'edge_counts_by_type',
#  'exclude_obsolete',
#  'go_fpath',
#  'header',
#  'ids_to_terms',
#  'namespaces',
#  'plot_go_subgraph',
#  'plot_go_subgraphs_true_vs_predicted',
#  'propagate_terms',
#  'relationship_types']
